# %%
from google.colab import drive

# %%
drive.mount('/Dataset/My Drive/Dataset/')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-68d00321cb0e> in <module>()
# ----> 1 drive.mount('/Dataset/My Drive/Dataset/')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#      97
#      98   if ' ' in mountpoint:
# ---> 99     raise ValueError('Mountpoint must not contain a space.')
#     100
#     101   mountpoint = _os.path.expanduser(mountpoint)
#
# ValueError: Mountpoint must not contain a space.

# %%
import os

# %%
tx = '/Dataset/My Drive/Dataset/dogs/'

# %%
a = os.listdir(tx)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-70471c6c4f30> in <module>()
# ----> 1 a = os.listdir(tx)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Dataset/My Drive/Dataset/dogs/'

# %%
len(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-1a2e6ec5f1e3> in <module>()
# ----> 1 len(a)
#
# NameError: name 'a' is not defined

# %% [markdown]
# # New Section
